# %% [markdown]
# # Sample a subset of responses and such

# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
import random

# %%
# get all the feature files
primary_screen = glob("/drive3/nphill22/projects/corsello_lab/20250525_manuscript/sherlock_copy/data/responses/primary_screen/*")

# %%
# get random 500 responses
random.seed(42)
primary_screen = random.sample(primary_screen, 500)

# %%
primary_screen
# Out:
# ['/drive3/nphill22/projects/corsello_lab/20250525_manuscript/sherlock_copy/data/responses/primary_screen/BRD-A40639672-234-18-0.csv',
#  '/drive3/nphill22/projects/corsello_lab/20250525_manuscript/sherlock_copy/data/responses/primary_screen/BRD-K28308851-303-01-8.csv',
#  '/drive3/nphill22/projects/corsello_lab/20250525_manuscript/sherlock_copy/data/responses/primary_screen/BRD-K74305673-001-06-2.csv',
#  '/drive3/nphill22/projects/corsello_lab/20250525_manuscript/sherlock_copy/data/responses/primary_screen/BRD-K83794243-001-01-8.csv',
#  '/drive3/nphill22/projects/corsello_lab/20250525_manuscript/sherlock_copy/data/responses/primary_screen/BRD-K16546375-001-01-4.csv',
#  '/drive3/nphill22/projects/corsello_lab/20250525_manuscript/sherlock_copy/data/responses/primary_screen/BRD-A61194565-003-27-0.csv',
#  '/drive3/nphill22/projects/corsello_lab/20250525_manuscript/sherlock_copy/data/responses/primary_screen/BRD-K95785345-300-14-8.csv',
# ...

# %%
output_directory = "/drive3/nphill22/projects/corsello_lab/20250525_manuscript/sherlock_copy/data/subset_responses/primary_screen"
# copy the directory from the primary_screen list to the output directory
import shutil
for file in primary_screen:
    shutil.copy(file, output_directory)

# %%
f
# Out:
# '/drive3/nphill22/projects/corsello_lab/20250525_manuscript/sherlock_copy/data/responses/primary_screen/BRD-A40639672-234-18-0.csv'
